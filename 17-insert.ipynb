# %%
import mysql.connector

db = mysql.connector.connect(

    host = "localhost",
    user= "root",
    password = "abc@123",
    database = "ecommerce"
)
cursor = db.cursor()

# %%
x = "insert into ecommerce.customer(customer_id,email,name,state,mobile) values(%s,%s,%s,%s,%s)"

# %%
y = [
    (615,"p@g1.com","Heena","UP",9716817710),
    (611,"p@g2.com","Heena1","UP",9716817710),
    (612,"p@g3.com","Heena2","UP",9716817710),
    (613,"p@g4.com","Heena3","UP",9716817710),
    (614,"p@g5.com","Heena4","UP",9716817710)

]

# %%
for i in y:
    cursor.execute(x,i)
    db.commit ()
