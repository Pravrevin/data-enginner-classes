# %%
import pandas as pd 
import mysql.connector

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password= "abc@123",
    database = "ecommerce"
)
cursor = db.cursor()

# %%
df = pd.read_csv("customer.csv",skiprows=3)
df
# Out:
#    customer_id       email    name state      mobile
# 0          701  abc1@g.com   Umesh    UK  9716817710
# 1          702  abc2@g.com  ramesh    UK  9716817710
# 2          703  abc3@g.com    sita    UK  9716817710
# 3          704  abc4@g.com    gita    UK  9716817710
# 4          705  abc5@g.com   Rahul    UK  9716817710
# 5          706  abc6@g.com  himesh    UK  9716817710

# %%
sql = "insert into ecommerce.customer (customer_id,email,name,state,mobile) values(%s,%s,%s,%s,%s)"

# %%
data = df.values.tolist()
print(data)
# Out:
# [[701, 'abc1@g.com', 'Umesh', 'UK', 9716817710], [702, 'abc2@g.com', 'ramesh', 'UK', 9716817710], [703, 'abc3@g.com', 'sita', 'UK', 9716817710], [704, 'abc4@g.com', 'gita', 'UK', 9716817710], [705, 'abc5@g.com', 'Rahul', 'UK', 9716817710], [706, 'abc6@g.com', 'himesh', 'UK', 9716817710]]

# %%
cursor.executemany(sql,data)
db.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '701' for key 'customer.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cursor.executemany(sql,data)
#       2 db.commit()
#
# ...
