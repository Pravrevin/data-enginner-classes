# %%
import mysql.connector

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password= "abc@123",
    database = "ecommerce"
)
cursor = db.cursor()

# %%
cursor.execute("select * from customer")
result = cursor.fetchall()
print(result)
# Out:
# [(1, 'abc@g.com', 'Raj', 'UP', 123456789), (2, 'tty@g.com', 'Rohan', 'Pune', 9716817711), (3, 'ab@g.com', 'Samra', 'UP', 971681772), (11, 'aer@g.com', 'Ram', 'Delhi', 971687710), (12, 'abtt@g.com', 'Sushma', 'UK', 971817710), (13, 'abt@g.com', 'Vishal', 'Mumbai', 971617710), (33, 'abbb@g.com', 'rahul', 'UP', 97168172)]
